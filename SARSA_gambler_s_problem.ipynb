# %%
import numpy  as np
import matplotlib.pyplot as plt

# %%
N_states = 100  
States = list(range(0,N_states+1)) 
rewards = np.zeros(N_states+1)  
rewards[100] = 1.0  
Policy = [0] * 101 
Max_N_actions = 51
alpha = 0.6
gamma=1

# %%
def eps_greedy(a, eps, state):
    p = np.random.random()
    posible_actions = [i for i in range(min(state + 1, 101 - state))]
    if p < (1 - eps):
        return a
    else:
        return np.random.choice(posible_actions)

# %%
def SARSA(p_head):
  Q_Sarsa = np.zeros([N_states+ 1, Max_N_actions])
  G = 0
  episodes = 1000
  rewardTracker = []
  eps=0.3

  for state_init in reversed(States[1:100]): 
      print("-----------------------------")
      print("Number of the current State: ", state_init)
      for episode in range(1,episodes+1):
          Terminal = False
          G, reward = 0,0
          state = state_init
          List_of_posible_actions = [i for i in range(1, min(state + 1, 101 - state))]
          action = np.argmax(Q_Sarsa[state]) 
          if action == 0 and state != 0: 
              action = np.random.choice(List_of_posible_actions)
          iteration=1;
          action= eps_greedy(action, eps, state)
          while Terminal != True:
              iteration+=1
              
              Coin_toss_outcome = np.random.random() 
              
              if Coin_toss_outcome <= Head_probability: 
                  state2 = state + action 
              else: 
                  state2 = state - action 
              
              reward = rewards[state2]
              if (state2 == 100) or (state2 ==0 ):
                  Terminal = True
                  
              action2 = np.argmax(Q_Sarsa[state2])
              if action2 == 0 and state2 != 0 : 
                  action2 = np.random.choice([i for i in range(min(state2 + 1, 101 - state2))]) 
              action2 = eps_greedy(action2, eps, state2)
              Q_Sarsa[state,action] += alpha * ((reward + gamma*(Q_Sarsa[state2, action2]  - Q_Sarsa[state,action]))) 
              # print("episode: ",episode ,"---iteration: ", iteration, "---state:", state,"---action:", action, "---Q function: ", Q_Sarsa[state, action])
              G += reward
              state = state2 
              action = action2 
          rewardTracker.append(G)

          if episode % 1000 == 0:
              print('Episode {} Reward: {}   Total Average Reward: {} '.format(episode,G, sum(rewardTracker)/len(rewardTracker)))


  value_function = []
  policy = []
  for state in States[1:100]: 
      value_function.append(np.max(Q_Sarsa[state]))
      policy.append(np.argmax(Q_Sarsa[state]))
      
  plt.plot(value_function)
  plt.show()

  plt.plot(policy)
  plt.show()

# %%
Head_probability = 0.25
SARSA(Head_probability)
# Out:
# -----------------------------
# Number of the current State:  99
# Episode 1000 Reward: 0.0   Total Average Reward: 0.68
# -----------------------------
# Number of the current State:  98
# Episode 1000 Reward: 0.0   Total Average Reward: 0.6285
# -----------------------------
# Number of the current State:  97
# Episode 1000 Reward: 1.0   Total Average Reward: 0.5943333333333334
# -----------------------------
# Number of the current State:  96
# Episode 1000 Reward: 0.0   Total Average Reward: 0.56425
# -----------------------------
# Number of the current State:  95
# Episode 1000 Reward: 1.0   Total Average Reward: 0.5364
# -----------------------------
# Number of the current State:  94
# Episode 1000 Reward: 0.0   Total Average Reward: 0.5151666666666667
# -----------------------------
# Number of the current State:  93
# Episode 1000 Reward: 0.0   Total Average Reward: 0.4967142857142857
# -----------------------------
# Number of the current State:  92
# Episode 1000 Reward: 0.0   Total Average Reward: 0.47725
# -----------------------------
# Number of the current State:  91
# Episode 1000 Reward: 1.0   Total Average Reward: 0.46155555555555555
# -----------------------------
# Number of the current State:  90
# Episode 1000 Reward: 0.0   Total Average Reward: 0.4436
# -----------------------------
# Number of the current State:  89
# Episode 1000 Reward: 1.0   Total Average Reward: 0.4264545454545455
# -----------------------------
# Number of the current State:  88
# Episode 1000 Reward: 0.0   Total Average Reward: 0.41541666666666666
# -----------------------------
# Number of the current State:  87
# Episode 1000 Reward: 1.0   Total Average Reward: 0.4046153846153846
# -----------------------------
# Number of the current State:  86
# Episode 1000 Reward: 0.0   Total Average Reward: 0.39321428571428574
# -----------------------------
# Number of the current State:  85
# Episode 1000 Reward: 0.0   Total Average Reward: 0.384
# -----------------------------
# Number of the current State:  84
# Episode 1000 Reward: 0.0   Total Average Reward: 0.3729375
# -----------------------------
# Number of the current State:  83
# Episode 1000 Reward: 1.0   Total Average Reward: 0.3625294117647059
# -----------------------------
# Number of the current State:  82
# Episode 1000 Reward: 0.0   Total Average Reward: 0.3555
# -----------------------------
# Number of the current State:  81
# Episode 1000 Reward: 0.0   Total Average Reward: 0.3479473684210526
# -----------------------------
# Number of the current State:  80
# Episode 1000 Reward: 0.0   Total Average Reward: 0.3413
# -----------------------------
# Number of the current State:  79
# Episode 1000 Reward: 0.0   Total Average Reward: 0.335
# -----------------------------
# Number of the current State:  78
# Episode 1000 Reward: 0.0   Total Average Reward: 0.32795454545454544
# -----------------------------
# Number of the current State:  77
# Episode 1000 Reward: 1.0   Total Average Reward: 0.32156521739130434
# -----------------------------
# Number of the current State:  76
# Episode 1000 Reward: 0.0   Total Average Reward: 0.3164166666666667
# -----------------------------
# Number of the current State:  75
# Episode 1000 Reward: 0.0   Total Average Reward: 0.30996
# -----------------------------
# Number of the current State:  74
# Episode 1000 Reward: 0.0   Total Average Reward: 0.30353846153846153
# -----------------------------
# Number of the current State:  73
# Episode 1000 Reward: 0.0   Total Average Reward: 0.2977037037037037
# -----------------------------
# Number of the current State:  72
# Episode 1000 Reward: 0.0   Total Average Reward: 0.29328571428571426
# -----------------------------
# Number of the current State:  71
# Episode 1000 Reward: 0.0   Total Average Reward: 0.28772413793103446
# -----------------------------
# Number of the current State:  70
# Episode 1000 Reward: 1.0   Total Average Reward: 0.2825666666666667
# -----------------------------
# Number of the current State:  69
# Episode 1000 Reward: 0.0   Total Average Reward: 0.2768709677419355
# -----------------------------
# Number of the current State:  68
# Episode 1000 Reward: 0.0   Total Average Reward: 0.2725
# -----------------------------
# Number of the current State:  67
# Episode 1000 Reward: 0.0   Total Average Reward: 0.26821212121212124
# -----------------------------
# Number of the current State:  66
# Episode 1000 Reward: 1.0   Total Average Reward: 0.26394117647058823
# -----------------------------
# Number of the current State:  65
# Episode 1000 Reward: 0.0   Total Average Reward: 0.2600857142857143
# -----------------------------
# Number of the current State:  64
# Episode 1000 Reward: 0.0   Total Average Reward: 0.25608333333333333
# -----------------------------
# Number of the current State:  63
# Episode 1000 Reward: 0.0   Total Average Reward: 0.2522972972972973
# -----------------------------
# Number of the current State:  62
# Episode 1000 Reward: 0.0   Total Average Reward: 0.24952631578947368
# -----------------------------
# Number of the current State:  61
# Episode 1000 Reward: 0.0   Total Average Reward: 0.24615384615384617
# -----------------------------
# Number of the current State:  60
# Episode 1000 Reward: 0.0   Total Average Reward: 0.242325
# -----------------------------
# Number of the current State:  59
# Episode 1000 Reward: 0.0   Total Average Reward: 0.23858536585365853
# -----------------------------
# Number of the current State:  58
# Episode 1000 Reward: 0.0   Total Average Reward: 0.23485714285714285
# -----------------------------
# Number of the current State:  57
# Episode 1000 Reward: 0.0   Total Average Reward: 0.23162790697674418
# -----------------------------
# Number of the current State:  56
# Episode 1000 Reward: 0.0   Total Average Reward: 0.22818181818181818
# -----------------------------
# Number of the current State:  55
# Episode 1000 Reward: 0.0   Total Average Reward: 0.22446666666666668
# -----------------------------
# Number of the current State:  54
# Episode 1000 Reward: 0.0   Total Average Reward: 0.2214782608695652
# -----------------------------
# Number of the current State:  53
# Episode 1000 Reward: 0.0   Total Average Reward: 0.21859574468085105
# -----------------------------
# Number of the current State:  52
# Episode 1000 Reward: 0.0   Total Average Reward: 0.21560416666666668
# -----------------------------
# Number of the current State:  51
# Episode 1000 Reward: 0.0   Total Average Reward: 0.21248979591836734
# -----------------------------
# Number of the current State:  50
# Episode 1000 Reward: 0.0   Total Average Reward: 0.2096
# -----------------------------
# Number of the current State:  49
# Episode 1000 Reward: 0.0   Total Average Reward: 0.2069607843137255
# -----------------------------
# Number of the current State:  48
# Episode 1000 Reward: 0.0   Total Average Reward: 0.20386538461538461
# -----------------------------
# Number of the current State:  47
# Episode 1000 Reward: 0.0   Total Average Reward: 0.2012264150943396
# -----------------------------
# Number of the current State:  46
# Episode 1000 Reward: 0.0   Total Average Reward: 0.1982962962962963
# -----------------------------
# Number of the current State:  45
# Episode 1000 Reward: 0.0   Total Average Reward: 0.19554545454545455
# -----------------------------
# Number of the current State:  44
# Episode 1000 Reward: 0.0   Total Average Reward: 0.1929107142857143
# -----------------------------
# Number of the current State:  43
# Episode 1000 Reward: 0.0   Total Average Reward: 0.19036842105263158
# -----------------------------
# Number of the current State:  42
# Episode 1000 Reward: 0.0   Total Average Reward: 0.18767241379310345
# -----------------------------
# Number of the current State:  41
# Episode 1000 Reward: 0.0   Total Average Reward: 0.1850677966101695
# -----------------------------
# Number of the current State:  40
# Episode 1000 Reward: 0.0   Total Average Reward: 0.18273333333333333
# -----------------------------
# Number of the current State:  39
# Episode 1000 Reward: 0.0   Total Average Reward: 0.1802622950819672
# -----------------------------
# Number of the current State:  38
# Episode 1000 Reward: 0.0   Total Average Reward: 0.17767741935483872
# -----------------------------
# Number of the current State:  37
# Episode 1000 Reward: 0.0   Total Average Reward: 0.17533333333333334
# -----------------------------
# Number of the current State:  36
# Episode 1000 Reward: 0.0   Total Average Reward: 0.173203125
# -----------------------------
# Number of the current State:  35
# Episode 1000 Reward: 0.0   Total Average Reward: 0.17087692307692307
# -----------------------------
# Number of the current State:  34
# Episode 1000 Reward: 0.0   Total Average Reward: 0.16857575757575757
# -----------------------------
# Number of the current State:  33
# Episode 1000 Reward: 0.0   Total Average Reward: 0.16634328358208955
# -----------------------------
# Number of the current State:  32
# Episode 1000 Reward: 0.0   Total Average Reward: 0.16422058823529412
# -----------------------------
# Number of the current State:  31
# Episode 1000 Reward: 0.0   Total Average Reward: 0.1621304347826087
# -----------------------------
# Number of the current State:  30
# Episode 1000 Reward: 0.0   Total Average Reward: 0.16007142857142856
# -----------------------------
# Number of the current State:  29
# Episode 1000 Reward: 0.0   Total Average Reward: 0.158
# -----------------------------
# Number of the current State:  28
# Episode 1000 Reward: 0.0   Total Average Reward: 0.15597222222222223
# -----------------------------
# Number of the current State:  27
# Episode 1000 Reward: 0.0   Total Average Reward: 0.15408219178082191
# -----------------------------
# Number of the current State:  26
# Episode 1000 Reward: 0.0   Total Average Reward: 0.1521081081081081
# -----------------------------
# Number of the current State:  25
# Episode 1000 Reward: 0.0   Total Average Reward: 0.15014666666666668
# -----------------------------
# Number of the current State:  24
# Episode 1000 Reward: 0.0   Total Average Reward: 0.1483157894736842
# -----------------------------
# Number of the current State:  23
# Episode 1000 Reward: 0.0   Total Average Reward: 0.14657142857142857
# -----------------------------
# Number of the current State:  22
# Episode 1000 Reward: 0.0   Total Average Reward: 0.1448076923076923
# -----------------------------
# Number of the current State:  21
# Episode 1000 Reward: 0.0   Total Average Reward: 0.14310126582278482
# -----------------------------
# Number of the current State:  20
# Episode 1000 Reward: 0.0   Total Average Reward: 0.141375
# -----------------------------
# Number of the current State:  19
# Episode 1000 Reward: 0.0   Total Average Reward: 0.1397283950617284
# -----------------------------
# Number of the current State:  18
# Episode 1000 Reward: 0.0   Total Average Reward: 0.13808536585365855
# -----------------------------
# Number of the current State:  17
# Episode 1000 Reward: 0.0   Total Average Reward: 0.1364457831325301
# -----------------------------
# Number of the current State:  16
# Episode 1000 Reward: 0.0   Total Average Reward: 0.13490476190476192
# -----------------------------
# Number of the current State:  15
# Episode 1000 Reward: 0.0   Total Average Reward: 0.13331764705882354
# -----------------------------
# Number of the current State:  14
# Episode 1000 Reward: 0.0   Total Average Reward: 0.13180232558139535
# -----------------------------
# Number of the current State:  13
# Episode 1000 Reward: 0.0   Total Average Reward: 0.13028735632183908
# -----------------------------
# Number of the current State:  12
# Episode 1000 Reward: 0.0   Total Average Reward: 0.12882954545454545
# -----------------------------
# Number of the current State:  11
# Episode 1000 Reward: 0.0   Total Average Reward: 0.1273932584269663
# -----------------------------
# Number of the current State:  10
# Episode 1000 Reward: 0.0   Total Average Reward: 0.1260111111111111
# -----------------------------
# Number of the current State:  9
# Episode 1000 Reward: 0.0   Total Average Reward: 0.12462637362637363
# -----------------------------
# Number of the current State:  8
# Episode 1000 Reward: 0.0   Total Average Reward: 0.12327173913043478
# -----------------------------
# Number of the current State:  7
# Episode 1000 Reward: 0.0   Total Average Reward: 0.12194623655913979
# -----------------------------
# Number of the current State:  6
# Episode 1000 Reward: 0.0   Total Average Reward: 0.12064893617021277
# -----------------------------
# Number of the current State:  5
# Episode 1000 Reward: 0.0   Total Average Reward: 0.11937894736842106
# -----------------------------
# Number of the current State:  4
# Episode 1000 Reward: 0.0   Total Average Reward: 0.11813541666666667
# -----------------------------
# Number of the current State:  3
# Episode 1000 Reward: 0.0   Total Average Reward: 0.11691752577319588
# -----------------------------
# Number of the current State:  2
# Episode 1000 Reward: 0.0   Total Average Reward: 0.11572448979591837
# -----------------------------
# Number of the current State:  1
# Episode 1000 Reward: 0.0   Total Average Reward: 0.11455555555555555

# %%
Head_probability = 0.55
SARSA(Head_probability)
# Out:
# -----------------------------
# Number of the current State:  99
# Episode 1000 Reward: 1.0   Total Average Reward: 0.996
# -----------------------------
# Number of the current State:  98
# Episode 1000 Reward: 1.0   Total Average Reward: 0.9935
# -----------------------------
# Number of the current State:  97
# Episode 1000 Reward: 1.0   Total Average Reward: 0.9923333333333333
# -----------------------------
# Number of the current State:  96
# Episode 1000 Reward: 1.0   Total Average Reward: 0.991
# -----------------------------
# Number of the current State:  95
# Episode 1000 Reward: 1.0   Total Average Reward: 0.988
# -----------------------------
# Number of the current State:  94
# Episode 1000 Reward: 1.0   Total Average Reward: 0.9848333333333333
# -----------------------------
# Number of the current State:  93
# Episode 1000 Reward: 1.0   Total Average Reward: 0.981
# -----------------------------
# Number of the current State:  92
# Episode 1000 Reward: 1.0   Total Average Reward: 0.979
# -----------------------------
# Number of the current State:  91
# Episode 1000 Reward: 1.0   Total Average Reward: 0.9767777777777777
# -----------------------------
# Number of the current State:  90
# Episode 1000 Reward: 1.0   Total Average Reward: 0.9736
# -----------------------------
# Number of the current State:  89
# Episode 1000 Reward: 1.0   Total Average Reward: 0.9696363636363636
# -----------------------------
# Number of the current State:  88
# Episode 1000 Reward: 1.0   Total Average Reward: 0.966
# -----------------------------
# Number of the current State:  87
# Episode 1000 Reward: 1.0   Total Average Reward: 0.9626153846153847
# -----------------------------
# Number of the current State:  86
# Episode 1000 Reward: 1.0   Total Average Reward: 0.9600714285714286
# -----------------------------
# Number of the current State:  85
# Episode 1000 Reward: 0.0   Total Average Reward: 0.9559333333333333
# -----------------------------
# Number of the current State:  84
# Episode 1000 Reward: 1.0   Total Average Reward: 0.9530625
# -----------------------------
# Number of the current State:  83
# Episode 1000 Reward: 1.0   Total Average Reward: 0.9508235294117647
# -----------------------------
# Number of the current State:  82
# Episode 1000 Reward: 1.0   Total Average Reward: 0.9473333333333334
# -----------------------------
# Number of the current State:  81
# Episode 1000 Reward: 1.0   Total Average Reward: 0.9434210526315789
# -----------------------------
# Number of the current State:  80
# Episode 1000 Reward: 1.0   Total Average Reward: 0.94055
# -----------------------------
# Number of the current State:  79
# Episode 1000 Reward: 1.0   Total Average Reward: 0.9378571428571428
# -----------------------------
# Number of the current State:  78
# Episode 1000 Reward: 1.0   Total Average Reward: 0.9341818181818182
# -----------------------------
# Number of the current State:  77
# Episode 1000 Reward: 1.0   Total Average Reward: 0.9303913043478261
# -----------------------------
# Number of the current State:  76
# Episode 1000 Reward: 1.0   Total Average Reward: 0.9265
# -----------------------------
# Number of the current State:  75
# Episode 1000 Reward: 1.0   Total Average Reward: 0.92284
# -----------------------------
# Number of the current State:  74
# Episode 1000 Reward: 0.0   Total Average Reward: 0.9200769230769231
# -----------------------------
# Number of the current State:  73
# Episode 1000 Reward: 1.0   Total Average Reward: 0.9168148148148149
# -----------------------------
# Number of the current State:  72
# Episode 1000 Reward: 1.0   Total Average Reward: 0.9132142857142858
# -----------------------------
# Number of the current State:  71
# Episode 1000 Reward: 0.0   Total Average Reward: 0.9095172413793103
# -----------------------------
# Number of the current State:  70
# Episode 1000 Reward: 1.0   Total Average Reward: 0.9050333333333334
# -----------------------------
# Number of the current State:  69
# Episode 1000 Reward: 1.0   Total Average Reward: 0.9015161290322581
# -----------------------------
# Number of the current State:  68
# Episode 1000 Reward: 0.0   Total Average Reward: 0.89803125
# -----------------------------
# Number of the current State:  67
# Episode 1000 Reward: 0.0   Total Average Reward: 0.8947272727272727
# -----------------------------
# Number of the current State:  66
# Episode 1000 Reward: 1.0   Total Average Reward: 0.8911764705882353
# -----------------------------
# Number of the current State:  65
# Episode 1000 Reward: 1.0   Total Average Reward: 0.8874857142857143
# -----------------------------
# Number of the current State:  64
# Episode 1000 Reward: 1.0   Total Average Reward: 0.8841666666666667
# -----------------------------
# Number of the current State:  63
# Episode 1000 Reward: 1.0   Total Average Reward: 0.8804324324324324
# -----------------------------
# Number of the current State:  62
# Episode 1000 Reward: 1.0   Total Average Reward: 0.8768157894736842
# -----------------------------
# Number of the current State:  61
# Episode 1000 Reward: 1.0   Total Average Reward: 0.8729743589743589
# -----------------------------
# Number of the current State:  60
# Episode 1000 Reward: 1.0   Total Average Reward: 0.868975
# -----------------------------
# Number of the current State:  59
# Episode 1000 Reward: 1.0   Total Average Reward: 0.8650243902439024
# -----------------------------
# Number of the current State:  58
# Episode 1000 Reward: 0.0   Total Average Reward: 0.8603571428571428
# -----------------------------
# Number of the current State:  57
# Episode 1000 Reward: 0.0   Total Average Reward: 0.8555348837209302
# -----------------------------
# Number of the current State:  56
# Episode 1000 Reward: 0.0   Total Average Reward: 0.8514772727272727
# -----------------------------
# Number of the current State:  55
# Episode 1000 Reward: 0.0   Total Average Reward: 0.8472888888888889
# -----------------------------
# Number of the current State:  54
# Episode 1000 Reward: 1.0   Total Average Reward: 0.8433695652173913
# -----------------------------
# Number of the current State:  53
# Episode 1000 Reward: 0.0   Total Average Reward: 0.8391702127659575
# -----------------------------
# Number of the current State:  52
# Episode 1000 Reward: 0.0   Total Average Reward: 0.83475
# -----------------------------
# Number of the current State:  51
# Episode 1000 Reward: 1.0   Total Average Reward: 0.8303469387755102
# -----------------------------
# Number of the current State:  50
# Episode 1000 Reward: 1.0   Total Average Reward: 0.82562
# -----------------------------
# Number of the current State:  49
# Episode 1000 Reward: 0.0   Total Average Reward: 0.8215490196078431
# -----------------------------
# Number of the current State:  48
# Episode 1000 Reward: 1.0   Total Average Reward: 0.8173653846153847
# -----------------------------
# Number of the current State:  47
# Episode 1000 Reward: 1.0   Total Average Reward: 0.8135283018867925
# -----------------------------
# Number of the current State:  46
# Episode 1000 Reward: 0.0   Total Average Reward: 0.8092037037037038
# -----------------------------
# Number of the current State:  45
# Episode 1000 Reward: 0.0   Total Average Reward: 0.8049272727272727
# -----------------------------
# Number of the current State:  44
# Episode 1000 Reward: 1.0   Total Average Reward: 0.8004821428571428
# -----------------------------
# Number of the current State:  43
# Episode 1000 Reward: 1.0   Total Average Reward: 0.7961754385964912
# -----------------------------
# Number of the current State:  42
# Episode 1000 Reward: 0.0   Total Average Reward: 0.7919827586206897
# -----------------------------
# Number of the current State:  41
# Episode 1000 Reward: 0.0   Total Average Reward: 0.7881016949152543
# -----------------------------
# Number of the current State:  40
# Episode 1000 Reward: 0.0   Total Average Reward: 0.7837833333333334
# -----------------------------
# Number of the current State:  39
# Episode 1000 Reward: 1.0   Total Average Reward: 0.779655737704918
# -----------------------------
# Number of the current State:  38
# Episode 1000 Reward: 1.0   Total Average Reward: 0.7750322580645161
# -----------------------------
# Number of the current State:  37
# Episode 1000 Reward: 0.0   Total Average Reward: 0.7705714285714286
# -----------------------------
# Number of the current State:  36
# Episode 1000 Reward: 1.0   Total Average Reward: 0.7663125
# -----------------------------
# Number of the current State:  35
# Episode 1000 Reward: 1.0   Total Average Reward: 0.7616923076923077
# -----------------------------
# Number of the current State:  34
# Episode 1000 Reward: 0.0   Total Average Reward: 0.7573030303030303
# -----------------------------
# Number of the current State:  33
# Episode 1000 Reward: 0.0   Total Average Reward: 0.7527910447761194
# -----------------------------
# Number of the current State:  32
# Episode 1000 Reward: 0.0   Total Average Reward: 0.7483382352941177
# -----------------------------
# Number of the current State:  31
# Episode 1000 Reward: 1.0   Total Average Reward: 0.7438985507246377
# -----------------------------
# Number of the current State:  30
# Episode 1000 Reward: 0.0   Total Average Reward: 0.7394571428571428
# -----------------------------
# Number of the current State:  29
# Episode 1000 Reward: 1.0   Total Average Reward: 0.7347464788732394
# -----------------------------
# Number of the current State:  28
# Episode 1000 Reward: 0.0   Total Average Reward: 0.7303055555555555
# -----------------------------
# Number of the current State:  27
# Episode 1000 Reward: 1.0   Total Average Reward: 0.7256712328767123
# -----------------------------
# Number of the current State:  26
# Episode 1000 Reward: 1.0   Total Average Reward: 0.721027027027027
# -----------------------------
# Number of the current State:  25
# Episode 1000 Reward: 1.0   Total Average Reward: 0.71628
# -----------------------------
# Number of the current State:  24
# Episode 1000 Reward: 0.0   Total Average Reward: 0.7113421052631579
# -----------------------------
# Number of the current State:  23
# Episode 1000 Reward: 0.0   Total Average Reward: 0.7066753246753247
# -----------------------------
# Number of the current State:  22
# Episode 1000 Reward: 0.0   Total Average Reward: 0.7019358974358975
# -----------------------------
# Number of the current State:  21
# Episode 1000 Reward: 0.0   Total Average Reward: 0.6973670886075949
# -----------------------------
# Number of the current State:  20
# Episode 1000 Reward: 0.0   Total Average Reward: 0.6926625
# -----------------------------
# Number of the current State:  19
# Episode 1000 Reward: 1.0   Total Average Reward: 0.6877901234567901
# -----------------------------
# Number of the current State:  18
# Episode 1000 Reward: 0.0   Total Average Reward: 0.6827073170731708
# -----------------------------
# Number of the current State:  17
# Episode 1000 Reward: 0.0   Total Average Reward: 0.6779156626506024
# -----------------------------
# Number of the current State:  16
# Episode 1000 Reward: 1.0   Total Average Reward: 0.6728571428571428
# -----------------------------
# Number of the current State:  15
# Episode 1000 Reward: 1.0   Total Average Reward: 0.6680470588235294
# -----------------------------
# Number of the current State:  14
# Episode 1000 Reward: 0.0   Total Average Reward: 0.6629651162790697
# -----------------------------
# Number of the current State:  13
# Episode 1000 Reward: 0.0   Total Average Reward: 0.6577586206896552
# -----------------------------
# Number of the current State:  12
# Episode 1000 Reward: 0.0   Total Average Reward: 0.652625
# -----------------------------
# Number of the current State:  11
# Episode 1000 Reward: 0.0   Total Average Reward: 0.6475955056179775
# -----------------------------
# Number of the current State:  10
# Episode 1000 Reward: 0.0   Total Average Reward: 0.6423666666666666
# -----------------------------
# Number of the current State:  9
# Episode 1000 Reward: 0.0   Total Average Reward: 0.6372637362637362
# -----------------------------
# Number of the current State:  8
# Episode 1000 Reward: 0.0   Total Average Reward: 0.6319456521739131
# -----------------------------
# Number of the current State:  7
# Episode 1000 Reward: 0.0   Total Average Reward: 0.6266344086021506
# -----------------------------
# Number of the current State:  6
# Episode 1000 Reward: 0.0   Total Average Reward: 0.6213297872340425
# -----------------------------
# Number of the current State:  5
# Episode 1000 Reward: 0.0   Total Average Reward: 0.6160631578947369
# -----------------------------
# Number of the current State:  4
# Episode 1000 Reward: 0.0   Total Average Reward: 0.6105833333333334
# -----------------------------
# Number of the current State:  3
# Episode 1000 Reward: 0.0   Total Average Reward: 0.6050412371134021
# -----------------------------
# Number of the current State:  2
# Episode 1000 Reward: 0.0   Total Average Reward: 0.5993979591836734
# -----------------------------
# Number of the current State:  1
# Episode 1000 Reward: 0.0   Total Average Reward: 0.5936060606060606
